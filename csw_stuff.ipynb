# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import optuna
from optuna import Trial
from optuna.samplers import TPESampler
import xgboost as xgb
import joblib

from feature_engineering import compute_fastball_relative_features, compute_approach_angles, compute_adjusted_axis_deviation

# %%
df = pd.read_csv('statcast_data/df_all_spin.csv')

# %%
## Calculate vertical approach angle and horizontal approach angle (degrees) for each pitch
df = compute_approach_angles(df)

## Calculate adjusted axis deviation (degrees normalized for pitcher handedness) for each pitch
df = compute_adjusted_axis_deviation(df)

df = compute_fastball_relative_features(df)

# %%
df.description.value_counts()
# Out:
# description
# ball                       792435
# foul                       418067
# hit_into_play              414439
# called_strike              390569
# swinging_strike            255047
# blocked_ball                54861
# foul_tip                    23020
# swinging_strike_blocked     15260
# hit_by_pitch                 7133
# foul_bunt                    4029
# missed_bunt                   817
# pitchout                      127
# bunt_foul_tip                  87
# foul_pitchout                   1
# unknown_strike                  1
# Name: count, dtype: int64

# %%
csw = ['called_strike', 'swinging_strike', 'swinging_strike_blocked']

# %%
df['csw'] = df['description'].isin(csw).astype(int)

# %%
fastballs = ['FF', 'SI']
non_fastballs = ['FC', 'CH', 'FS', 'FO', 'KC', 'CU', 'SL', 'ST', 'SV', 'CS', 'SC']

# %%
df.loc[df.pitch_type.isin(fastballs), 'csw'].mean().round(3)
# Out:
# 0.268

# %%
df.loc[df.pitch_type.isin(non_fastballs), 'csw'].mean().round(3)
# Out:
# 0.287

# %%
df_fastballs = df.loc[(df['pitch_type'].isin(fastballs)) & (df['game_year'].isin([2020, 2021, 2022]))]
df_fastballs_holdout = df.loc[(df['pitch_type'].isin(fastballs)) & (df['game_year']==2023)]

# %%
fastball_features = [
    'release_speed', 'ax', 'ay', 'az', 'vaa', 'haa', 'axis_deviation_adj', 'plate_x', 'plate_z'
]
target = 'csw'

# %%
df_fastballs[fastball_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 843425 entries, 0 to 1717441
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   release_speed       843405 non-null  float64
#  1   ax                  843416 non-null  float64
#  2   ay                  843416 non-null  float64
#  3   az                  843416 non-null  float64
#  4   vaa                 843416 non-null  float64
#  5   haa                 843310 non-null  float64
#  6   axis_deviation_adj  825727 non-null  float64
#  7   plate_x             843416 non-null  float64
#  8   plate_z             843416 non-null  float64
# dtypes: float64(9)
# memory usage: 64.3 MB

# %%
df_fastballs = df_fastballs.dropna(subset=fastball_features)
df_fastballs = df_fastballs.dropna(subset=[target])

df_fastballs_holdout = df_fastballs_holdout.dropna(subset=fastball_features)
df_fastballs_holdout = df_fastballs_holdout.dropna(subset=[target])

# %%
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train, val = train_test_split(df_fastballs, test_size=0.3, random_state=10)

# %%
from sklearn.metrics import roc_auc_score
import xgboost as xgb

# Define the objective function for Optuna
def objective(trial: Trial) -> float:
    params = {
        'device': 'cuda',  # Use GPU acceleration
        'n_estimators': trial.suggest_int('n_estimators', 100, 200),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'gamma': trial.suggest_float('gamma', 0.1, 0.3),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 0.1),
        'scale_pos_weight': 2.7  # Class weight for positive class
    }
    model = xgb.XGBClassifier(**params)
    model.fit(train[fastball_features], train[target])

    val_preds = model.predict(val[fastball_features])
    val_error = roc_auc_score(val[target], val_preds)  # Use sklearn's roc auc score

    return val_error

# Run the Optuna optimization
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study.optimize(objective, n_trials=25)

# Print the best parameters
print(study.best_params)
# Out:
# [I 2023-09-24 14:24:50,063] A new study created in memory with name: no-name-dd2c94ab-1862-4c30-9d4d-ec5e6159aa38
# [I 2023-09-24 14:24:52,986] Trial 0 finished with value: 0.6855525820386597 and parameters: {'n_estimators': 137, 'max_depth': 10, 'learning_rate': 0.07346740023932911, 'gamma': 0.2197316968394073, 'reg_alpha': 0.02404167763981929}. Best is trial 0 with value: 0.6855525820386597.
# [I 2023-09-24 14:24:54,051] Trial 1 finished with value: 0.6797600429991083 and parameters: {'n_estimators': 115, 'max_depth': 3, 'learning_rate': 0.08675143843171859, 'gamma': 0.22022300234864176, 'reg_alpha': 0.0737265320016441}. Best is trial 0 with value: 0.6855525820386597.
# [I 2023-09-24 14:24:56,431] Trial 2 finished with value: 0.6858345384811926 and parameters: {'n_estimators': 102, 'max_depth': 10, 'learning_rate': 0.08341182143924175, 'gamma': 0.14246782213565523, 'reg_alpha': 0.02636424704863906}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:24:57,623] Trial 3 finished with value: 0.6811162812086857 and parameters: {'n_estimators': 118, 'max_depth': 5, 'learning_rate': 0.05295088673159155, 'gamma': 0.18638900372842315, 'reg_alpha': 0.036210622617823776}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:24:58,999] Trial 4 finished with value: 0.6794289726523874 and parameters: {'n_estimators': 161, 'max_depth': 4, 'learning_rate': 0.0299223202049866, 'gamma': 0.17327236865873835, 'reg_alpha': 0.05104629857953324}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:00,509] Trial 5 finished with value: 0.680825101166666 and parameters: {'n_estimators': 179, 'max_depth': 4, 'learning_rate': 0.051909209402947555, 'gamma': 0.21848291377240847, 'reg_alpha': 0.014180537144799797}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:01,904] Trial 6 finished with value: 0.6765752253615993 and parameters: {'n_estimators': 161, 'max_depth': 4, 'learning_rate': 0.0074401077055426725, 'gamma': 0.28977710745066665, 'reg_alpha': 0.09690688297671035}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:03,528] Trial 7 finished with value: 0.6789023149534522 and parameters: {'n_estimators': 181, 'max_depth': 5, 'learning_rate': 0.010669539286632005, 'gamma': 0.23684660530243137, 'reg_alpha': 0.04961372443656412}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:04,867] Trial 8 finished with value: 0.6759361136323057 and parameters: {'n_estimators': 112, 'max_depth': 6, 'learning_rate': 0.004404463590406622, 'gamma': 0.2818640804157564, 'reg_alpha': 0.03329019834400153}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:06,353] Trial 9 finished with value: 0.6816182819785782 and parameters: {'n_estimators': 166, 'max_depth': 5, 'learning_rate': 0.052486734096603274, 'gamma': 0.20934205586865592, 'reg_alpha': 0.026636900997297437}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:09,234] Trial 10 finished with value: 0.6847425768071423 and parameters: {'n_estimators': 138, 'max_depth': 10, 'learning_rate': 0.09698417396799874, 'gamma': 0.11897871172046659, 'reg_alpha': 0.011466649773470708}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:12,219] Trial 11 finished with value: 0.6857957173905471 and parameters: {'n_estimators': 137, 'max_depth': 10, 'learning_rate': 0.07342611181455744, 'gamma': 0.1429354414703336, 'reg_alpha': 0.02543175449651773}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:13,813] Trial 12 finished with value: 0.6846611217290447 and parameters: {'n_estimators': 103, 'max_depth': 8, 'learning_rate': 0.07473546949124663, 'gamma': 0.12978024831594914, 'reg_alpha': 0.040826439436398125}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:15,716] Trial 13 finished with value: 0.685542940568715 and parameters: {'n_estimators': 132, 'max_depth': 8, 'learning_rate': 0.07253712311890684, 'gamma': 0.14692895325093008, 'reg_alpha': 0.022968214094943436}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:17,821] Trial 14 finished with value: 0.6850932202343247 and parameters: {'n_estimators': 126, 'max_depth': 9, 'learning_rate': 0.09917921137863742, 'gamma': 0.11012284719782789, 'reg_alpha': 0.012374734349069686}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:20,370] Trial 15 finished with value: 0.6854914843000338 and parameters: {'n_estimators': 197, 'max_depth': 8, 'learning_rate': 0.06564004525405688, 'gamma': 0.15414436245680857, 'reg_alpha': 0.03906710310007259}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:22,222] Trial 16 finished with value: 0.6855338664368408 and parameters: {'n_estimators': 100, 'max_depth': 9, 'learning_rate': 0.08663269010240114, 'gamma': 0.10811700164440216, 'reg_alpha': 0.061857708184841494}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:24,003] Trial 17 finished with value: 0.6843475945988542 and parameters: {'n_estimators': 146, 'max_depth': 7, 'learning_rate': 0.0624705270275075, 'gamma': 0.13705194787681685, 'reg_alpha': 0.026447247428535634}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:27,036] Trial 18 finished with value: 0.6848545415312313 and parameters: {'n_estimators': 149, 'max_depth': 10, 'learning_rate': 0.08527746511449365, 'gamma': 0.16292516021148923, 'reg_alpha': 0.01965694727924588}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:29,237] Trial 19 finished with value: 0.6855324236574643 and parameters: {'n_estimators': 124, 'max_depth': 9, 'learning_rate': 0.061276609013574915, 'gamma': 0.10219783784875425, 'reg_alpha': 0.032903294512128874}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:30,688] Trial 20 finished with value: 0.681617677926981 and parameters: {'n_estimators': 112, 'max_depth': 7, 'learning_rate': 0.04484767368369534, 'gamma': 0.13031262226252685, 'reg_alpha': 0.04423942610533914}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:33,569] Trial 21 finished with value: 0.6853722228765775 and parameters: {'n_estimators': 138, 'max_depth': 10, 'learning_rate': 0.08010483014631539, 'gamma': 0.1885971031864537, 'reg_alpha': 0.02126291315689718}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:36,446] Trial 22 finished with value: 0.6852095773481647 and parameters: {'n_estimators': 138, 'max_depth': 10, 'learning_rate': 0.07344028454832749, 'gamma': 0.1693092397984463, 'reg_alpha': 0.03333829806689371}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:39,004] Trial 23 finished with value: 0.6853514732209219 and parameters: {'n_estimators': 154, 'max_depth': 9, 'learning_rate': 0.0912154767757049, 'gamma': 0.14668427362406858, 'reg_alpha': 0.0271199896437731}. Best is trial 2 with value: 0.6858345384811926.
# [I 2023-09-24 14:25:41,722] Trial 24 finished with value: 0.6853557929718195 and parameters: {'n_estimators': 127, 'max_depth': 10, 'learning_rate': 0.07846813155221195, 'gamma': 0.18704033291903713, 'reg_alpha': 0.017849467077560046}. Best is trial 2 with value: 0.6858345384811926.
# {'n_estimators': 102, 'max_depth': 10, 'learning_rate': 0.08341182143924175, 'gamma': 0.14246782213565523, 'reg_alpha': 0.02636424704863906}

# %%
params = study.best_params
params['device'] = 'cuda'
xgb_fastball_csw = xgb.XGBRegressor(**params)
xgb_fastball_csw.fit(df_fastballs[fastball_features], df_fastballs[target])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.14246782213565523, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.08341182143924175,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=102, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb_fastball_csw.save_model('models/xgb_fastball_csw.json')

# %%
xgb_fastball_csw = xgb.XGBRegressor()
xgb_fastball_csw.load_model('models/xgb_fastball_csw.json')

# %%
df_fastballs_holdout['xgb_csw'] = xgb_fastball_csw.predict(df_fastballs_holdout[fastball_features])

# %%
non_fastball_features = [
    'release_speed', 'release_spin_rate', 'ax', 'ay', 'az', 'velo_delta', 'spin_axis_delta',
    'vert_delta', 'horz_delta', 'vaa', 'haa', 'axis_deviation_adj', 'plate_x', 'plate_z'
]
target = 'csw'

# %%
df_non_fastballs = df.loc[df['pitch_type'].isin(non_fastballs) & (df['game_year'].isin([2020, 2021, 2022]))]
df_non_fastballs_holdout = df.loc[df['pitch_type'].isin(non_fastballs) & (df['game_year']==2023)]

# %%
df_non_fastballs[non_fastball_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 845674 entries, 1 to 1717442
# Data columns (total 14 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   release_speed       845633 non-null  float64
#  1   release_spin_rate   841683 non-null  float64
#  2   ax                  845643 non-null  float64
#  3   ay                  845643 non-null  float64
#  4   az                  845643 non-null  float64
#  5   velo_delta          830506 non-null  float64
#  6   spin_axis_delta     821952 non-null  float64
#  7   vert_delta          830515 non-null  float64
#  8   horz_delta          830515 non-null  float64
#  9   vaa                 845643 non-null  float64
#  10  haa                 845539 non-null  float64
#  11  axis_deviation_adj  821952 non-null  float64
#  12  plate_x             845643 non-null  float64
#  13  plate_z             845643 non-null  float64
# dtypes: float64(14)
# memory usage: 96.8 MB

# %%
df_non_fastballs = df_non_fastballs.dropna(subset=non_fastball_features)
df_non_fastballs = df_non_fastballs.dropna(subset=[target])

df_non_fastballs_holdout = df_non_fastballs_holdout.dropna(subset=non_fastball_features)
df_non_fastballs_holdout = df_non_fastballs_holdout.dropna(subset=[target])

# %%
# Split the data into training and testing sets
train, val = train_test_split(df_non_fastballs, test_size=0.3, random_state=10)

# %%
# Define the objective function for Optuna
def objective(trial: Trial) -> float:
    params = {
        'device': 'cuda',  # Use GPU acceleration
        'n_estimators': trial.suggest_int('n_estimators', 100, 200),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.1),
        'gamma': trial.suggest_float('gamma', 0.1, 0.3),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.01, 0.1),
        'scale_pos_weight': 2.7  # Class weight for positive class
    }
    model = xgb.XGBClassifier(**params)
    model.fit(train[fastball_features], train[target])

    val_preds = model.predict(val[fastball_features])
    val_error = roc_auc_score(val[target], val_preds)  # Use sklearn's roc auc score

    return val_error

# Run the Optuna optimization
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=42))
study.optimize(objective, n_trials=25)

params = study.best_params
params['device'] = 'cuda'
# Out:
# [I 2023-09-24 14:25:50,668] A new study created in memory with name: no-name-9ec14421-40c0-4661-924d-564c0ba635d4
# [I 2023-09-24 14:25:53,814] Trial 0 finished with value: 0.6572921540684148 and parameters: {'n_estimators': 137, 'max_depth': 10, 'learning_rate': 0.07346740023932911, 'gamma': 0.2197316968394073, 'reg_alpha': 0.02404167763981929}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:25:54,912] Trial 1 finished with value: 0.6444209405238094 and parameters: {'n_estimators': 115, 'max_depth': 3, 'learning_rate': 0.08675143843171859, 'gamma': 0.22022300234864176, 'reg_alpha': 0.0737265320016441}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:25:57,178] Trial 2 finished with value: 0.6564577152233649 and parameters: {'n_estimators': 102, 'max_depth': 10, 'learning_rate': 0.08341182143924175, 'gamma': 0.14246782213565523, 'reg_alpha': 0.02636424704863906}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:25:58,335] Trial 3 finished with value: 0.6456564713610884 and parameters: {'n_estimators': 118, 'max_depth': 5, 'learning_rate': 0.05295088673159155, 'gamma': 0.18638900372842315, 'reg_alpha': 0.036210622617823776}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:25:59,707] Trial 4 finished with value: 0.643834398132017 and parameters: {'n_estimators': 161, 'max_depth': 4, 'learning_rate': 0.0299223202049866, 'gamma': 0.17327236865873835, 'reg_alpha': 0.05104629857953324}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:01,209] Trial 5 finished with value: 0.645035211505848 and parameters: {'n_estimators': 179, 'max_depth': 4, 'learning_rate': 0.051909209402947555, 'gamma': 0.21848291377240847, 'reg_alpha': 0.014180537144799797}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:02,582] Trial 6 finished with value: 0.6406661633328812 and parameters: {'n_estimators': 161, 'max_depth': 4, 'learning_rate': 0.0074401077055426725, 'gamma': 0.28977710745066665, 'reg_alpha': 0.09690688297671035}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:04,194] Trial 7 finished with value: 0.6431283678998937 and parameters: {'n_estimators': 181, 'max_depth': 5, 'learning_rate': 0.010669539286632005, 'gamma': 0.23684660530243137, 'reg_alpha': 0.04961372443656412}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:05,488] Trial 8 finished with value: 0.6394085855067304 and parameters: {'n_estimators': 112, 'max_depth': 6, 'learning_rate': 0.004404463590406622, 'gamma': 0.2818640804157564, 'reg_alpha': 0.03329019834400153}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:06,967] Trial 9 finished with value: 0.64711447289643 and parameters: {'n_estimators': 166, 'max_depth': 5, 'learning_rate': 0.052486734096603274, 'gamma': 0.20934205586865592, 'reg_alpha': 0.026636900997297437}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:09,767] Trial 10 finished with value: 0.6566947558576917 and parameters: {'n_estimators': 137, 'max_depth': 10, 'learning_rate': 0.09698417396799874, 'gamma': 0.1035923751229639, 'reg_alpha': 0.011383096359529386}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:12,555] Trial 11 finished with value: 0.6571488285487374 and parameters: {'n_estimators': 137, 'max_depth': 10, 'learning_rate': 0.0980012008920355, 'gamma': 0.11711701368159778, 'reg_alpha': 0.010336328003186518}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:14,466] Trial 12 finished with value: 0.6549140441734349 and parameters: {'n_estimators': 137, 'max_depth': 8, 'learning_rate': 0.07206991545857305, 'gamma': 0.11037299008938897, 'reg_alpha': 0.01147923564597935}. Best is trial 0 with value: 0.6572921540684148.
# [I 2023-09-24 14:26:16,420] Trial 13 finished with value: 0.6573157579057911 and parameters: {'n_estimators': 141, 'max_depth': 8, 'learning_rate': 0.09989648855080585, 'gamma': 0.1533982145890739, 'reg_alpha': 0.022968214094943436}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:18,486] Trial 14 finished with value: 0.6550933008270466 and parameters: {'n_estimators': 148, 'max_depth': 8, 'learning_rate': 0.06902927412849075, 'gamma': 0.16017845789835627, 'reg_alpha': 0.04128700874469248}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:21,024] Trial 15 finished with value: 0.6570356274101717 and parameters: {'n_estimators': 197, 'max_depth': 8, 'learning_rate': 0.07148580241912776, 'gamma': 0.1471290026391932, 'reg_alpha': 0.02402054138738671}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:23,256] Trial 16 finished with value: 0.6564365711646669 and parameters: {'n_estimators': 132, 'max_depth': 9, 'learning_rate': 0.08423148853401989, 'gamma': 0.18999152051502508, 'reg_alpha': 0.05995402018268531}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:24,998] Trial 17 finished with value: 0.6553708911759399 and parameters: {'n_estimators': 151, 'max_depth': 7, 'learning_rate': 0.09656845666048008, 'gamma': 0.24436934343059125, 'reg_alpha': 0.0419268064493207}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:27,132] Trial 18 finished with value: 0.6545399218743758 and parameters: {'n_estimators': 125, 'max_depth': 9, 'learning_rate': 0.0659794409278967, 'gamma': 0.1769935806244773, 'reg_alpha': 0.022898503753891748}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:29,611] Trial 19 finished with value: 0.6570593954533485 and parameters: {'n_estimators': 152, 'max_depth': 9, 'learning_rate': 0.08138405056268412, 'gamma': 0.20014256111273637, 'reg_alpha': 0.03292372834899948}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:31,298] Trial 20 finished with value: 0.6547924173810894 and parameters: {'n_estimators': 145, 'max_depth': 7, 'learning_rate': 0.0998002211890167, 'gamma': 0.1322481220679241, 'reg_alpha': 0.019098605580700454}. Best is trial 13 with value: 0.6573157579057911.
# [I 2023-09-24 14:26:34,016] Trial 21 finished with value: 0.6573803738160806 and parameters: {'n_estimators': 129, 'max_depth': 10, 'learning_rate': 0.0995313132744015, 'gamma': 0.12026606066275078, 'reg_alpha': 0.010824764518357762}. Best is trial 21 with value: 0.6573803738160806.
# [I 2023-09-24 14:26:36,189] Trial 22 finished with value: 0.6566641858212313 and parameters: {'n_estimators': 127, 'max_depth': 9, 'learning_rate': 0.08891382882215312, 'gamma': 0.13408614569797916, 'reg_alpha': 0.018860139999043006}. Best is trial 21 with value: 0.6573803738160806.
# [I 2023-09-24 14:26:38,826] Trial 23 finished with value: 0.6572274518189576 and parameters: {'n_estimators': 125, 'max_depth': 10, 'learning_rate': 0.09168546666645788, 'gamma': 0.15959396617834204, 'reg_alpha': 0.0203632792079627}. Best is trial 21 with value: 0.6573803738160806.
# [I 2023-09-24 14:26:40,407] Trial 24 finished with value: 0.653889689822112 and parameters: {'n_estimators': 104, 'max_depth': 8, 'learning_rate': 0.07893953874387176, 'gamma': 0.12359191636496367, 'reg_alpha': 0.029221273283352316}. Best is trial 21 with value: 0.6573803738160806.

# %%
xgb_non_fastball_csw = xgb.XGBRegressor(**params)
xgb_non_fastball_csw.fit(df_non_fastballs[non_fastball_features], df_non_fastballs[target])
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.12026606066275078, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.0995313132744015,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=129, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
xgb_non_fastball_csw.save_model('models/xgb_non_fastball_csw.json')

# %%
xgb_non_fastball_csw = xgb.XGBRegressor()
xgb_non_fastball_csw.load_model('models/xgb_non_fastball_csw.json')

# %%
df_non_fastballs_holdout.loc[:, 'xgb_csw'] = xgb_non_fastball_csw.predict(df_non_fastballs_holdout.loc[:, non_fastball_features])

# %%
df_holdout = pd.concat([df_fastballs_holdout, df_non_fastballs_holdout])

# %%
df2 = df_holdout.groupby(['player_name', 'pitcher', 'pitch_type'], as_index=False)[['csw', 'xgb_csw', 'release_speed']] \
    .agg({'xgb_csw':'mean', 'release_speed':'count', 'csw':'mean'}) \
    .reset_index(drop=True) \
    .rename(columns={'release_speed':'pitches_thrown'})

# Flatten the multi-index in columns
df2.columns = ['_'.join(col).rstrip('_') if isinstance(col, tuple) else col for col in df2.columns.values]

# Rename the columns
df2 = df2.rename(columns={
    'pitches_thrown_count': 'pitches_thrown'})
df2 = df2.round(2)

# %%
df2.query('pitches_thrown > 100').sort_values('xgb_csw', ascending=False).head(50)
# Out:
#                player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw
# 442       Chapman, Aroldis   547973         SL     0.46             267  0.41
# 233             Bird, Jake   656234         CU     0.43             253  0.35
# 2264         Ryu, Hyun Jin   547943         CU     0.42             108  0.39
# 2498    Stephenson, Robert   596112         SL     0.41             184  0.45
# 797           Floro, Dylan   571670         SL     0.41             207  0.29
# 2529       Stripling, Ross   548389         KC     0.41             128  0.43
# 1762         Miller, Bobby   676272         CU     0.40             317  0.36
# 1961        Ortiz, Luis F.   656814         ST     0.40             113  0.33
# 1745  Merryweather, Julian   657240         SL     0.40             559  0.39
# 1585          López, Jorge   605347         KC     0.40             183  0.39
# 688           Duran, Jhoan   661395         CU     0.40             259  0.36
# 1081         Helsley, Ryan   664854         SL     0.40             175  0.43
# 2886        Wilson, Steven   621051         ST     0.39             560  0.30
# 1644         Marte, Yunior   628708         SL     0.39             291  0.36
# 2318         Scherzer, Max   453286         CU     0.39             306  0.35
# 2977         deGrom, Jacob   594798         SL     0.39             167  0.41
# 174          Baumann, Mike   657508         KC     0.38             262  0.29
# 1429        Lambert, Jimmy   669424         KC     0.38             107  0.37
# 2457         Soto, Gregory   642397         SL     0.38             352  0.39
# 806        Francis, Bowden   670102         CU     0.38             183  0.33
# 2126          Ragans, Cole   666142         CU     0.38             179  0.36
# 1312            Kelly, Joe   523260         KC     0.38             124  0.35
# 2150       Rasmussen, Drew   656876         FF     0.37             199  0.29
# 2199    Rodriguez, Grayson   680570         SL     0.37             288  0.29
# 640          Detmers, Reid   672282         CU     0.37             466  0.34
# 1700     McClanahan, Shane   663556         CU     0.37             309  0.36
# 117           Bachman, Sam   696147         SL     0.37             179  0.33
# 423         Castro, Miguel   612434         SL     0.37             384  0.34
# 1234          Jacques, Joe   682175         SL     0.37             152  0.37
# 2133         Raley, Brooks   548384         ST     0.37             321  0.32
# 1937        Ohtani, Shohei   660271         ST     0.37             725  0.36
# 2195    Rodriguez, Grayson   680570         CH     0.37             419  0.25
# 2348             Sears, JP   676664         SL     0.37             330  0.30
# 2765          Walker, Ryan   676254         SL     0.37             492  0.32
# 1257         Jiménez, Dany   666204         SL     0.36             173  0.31
# 2111        Quantrill, Cal   615698         CU     0.36             141  0.23
# 1147          Hjelle, Sean   663546         SI     0.36             205  0.35
# 2091             Puk, A.J.   640462         ST     0.36             358  0.33
# 2285     Sandoval, Patrick   663776         CU     0.36             215  0.43
# 1114     Hernández, Carlos   672578         KC     0.36             104  0.35
# 519          Cosgrove, Tom   676680         SL     0.36             383  0.34
# 129          Banks, Tanner   621383         CU     0.36             143  0.26
# 2099           Pérez, Eury   691587         SL     0.36             459  0.35
# 1098         Herget, Jimmy   623474         CU     0.36             156  0.29
# 739         Falter, Bailey   663559         CU     0.36             280  0.27
# 2713     Verlander, Justin   434378         CU     0.36             445  0.31
# 2129          Ragans, Cole   666142         SL     0.36             146  0.36
# 1370         Kirby, George   669923         CU     0.36             314  0.32
# 2525      Strider, Spencer   675911         SL     0.36             955  0.42
# 715        Eovaldi, Nathan   543135         CU     0.36             258  0.35

# %%
def top_pitches(df, pitch_types, min_pitches=100, top_n=50, ascending=False):
    """
    Returns the top n pitches in pitch_score_percentile for a selected pitch type(s) 
    with an option to filter number of pitches_thrown.

    Parameters:
    df (pandas.DataFrame): DataFrame containing the pitch data.
    pitch_types (list): List of pitch types to consider.
    min_pitches (int): Minimum number of pitches thrown to consider.
    top_n (int): Number of top pitches to return.

    Returns:
    pandas.DataFrame: DataFrame containing the top n pitches.
    """
    if isinstance(pitch_types, str):
        pitch_types = [pitch_types]

    return (df.loc[df['pitch_type'].isin(pitch_types)]
              .query('pitches_thrown > @min_pitches')
              .sort_values('xgb_csw', ascending=ascending)
              .head(top_n))

# %%
top_pitches(df2, 'SI', min_pitches=100, top_n=50)
# Out:
#               player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw
# 1147         Hjelle, Sean   663546         SI     0.36             205  0.35
# 2585  Sánchez, Cristopher   650911         SI     0.35             606  0.33
# 85        Anderson, Grant   681982         SI     0.34             167  0.31
# 1507    Llovera, Mauricio   661440         SI     0.34             327  0.31
# 455          Cimber, Adam   643256         SI     0.33             110  0.34
# 552      Criswell, Cooper   681867         SI     0.33             167  0.29
# 2649         Topa, Justin   623437         SI     0.33             422  0.31
# 1177        Houck, Tanner   656557         SI     0.33             439  0.30
# 393         Cano, Yennier   666974         SI     0.33             526  0.29
# 2803          Webb, Logan   657277         SI     0.32            1030  0.35
# 1201        Hunter, Tommy   488984         SI     0.32             144  0.37
# 2950      Yarbrough, Ryan   642232         SI     0.32             368  0.31
# 240             Blach, Ty   621389         SI     0.32             554  0.30
# 1021          Hader, Josh   623352         SI     0.32             686  0.28
# 2764         Walker, Ryan   676254         SI     0.31             481  0.34
# 1538          Loup, Aaron   571901         SI     0.31             419  0.30
# 1086      Hendricks, Kyle   543294         SI     0.31             688  0.29
# 2633       Thompson, Ryan   657044         SI     0.31             222  0.27
# 2224        Rogers, Tyler   643511         SI     0.31             523  0.26
# 1921          Nola, Aaron   605400         SI     0.31             552  0.30
# 2610       Teheran, Julio   527054         SI     0.31             356  0.25
# 832       Fulmer, Michael   605242         SI     0.31             105  0.27
# 2515         Strahm, Matt   621381         SI     0.31             249  0.27
# 204   Bernardino, Brennan   657514         SI     0.31             458  0.32
# 886      Garrett, Braxton   666129         SI     0.31             714  0.33
# 1010        Greinke, Zack   425844         SI     0.31             317  0.27
# 2927       Woodford, Jake   663765         SI     0.31             381  0.31
# 1305        Keller, Mitch   656605         SI     0.30             664  0.32
# 485            Cobb, Alex   502171         SI     0.30             972  0.31
# 1162         Holmes, Clay   605280         SI     0.30             666  0.27
# 914          Gibson, Kyle   502043         SI     0.30             725  0.28
# 1425        La Sorsa, Joe   686747         SI     0.30             243  0.34
# 1407         Kremer, Dean   665152         SI     0.30             399  0.29
# 572            Cuas, Jose   621016         SI     0.30             532  0.30
# 449         Chavez, Jesse   445926         SI     0.30             146  0.36
# 1365        King, Michael   650633         SI     0.30             471  0.38
# 2402        Skubal, Tarik   669373         SI     0.30             128  0.27
# 686         Dunning, Dane   641540         SI     0.30             837  0.28
# 796          Floro, Dylan   571670         SI     0.30             288  0.31
# 2966         Zerpa, Angel   672582         SI     0.30             131  0.28
# 1144            Hill, Tim   657612         SI     0.30             301  0.26
# 2278          Sale, Chris   519242         SI     0.30             105  0.23
# 1753       Mikolas, Miles   571945         SI     0.30             743  0.25
# 2218       Rogers, Taylor   573124         SI     0.30             324  0.36
# 200         Bello, Brayan   678394         SI     0.30             886  0.29
# 165        Bassitt, Chris   605135         SI     0.30            1143  0.33
# 1789         Milner, Hoby   571948         SI     0.30             280  0.28
# 2751     Wainwright, Adam   425794         SI     0.30             526  0.26
# 254       Bleier, Richard   542947         SI     0.30             191  0.32
# 71         Alvarado, José   621237         SI     0.30             391  0.32

# %%
top_pitches(df2, 'SL', min_pitches=100, top_n=50)
# Out:
#                player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw
# 442       Chapman, Aroldis   547973         SL     0.46             267  0.41
# 797           Floro, Dylan   571670         SL     0.41             207  0.29
# 2498    Stephenson, Robert   596112         SL     0.41             184  0.45
# 1745  Merryweather, Julian   657240         SL     0.40             559  0.39
# 1081         Helsley, Ryan   664854         SL     0.40             175  0.43
# 2977         deGrom, Jacob   594798         SL     0.39             167  0.41
# 1644         Marte, Yunior   628708         SL     0.39             291  0.36
# 2457         Soto, Gregory   642397         SL     0.38             352  0.39
# 2348             Sears, JP   676664         SL     0.37             330  0.30
# 117           Bachman, Sam   696147         SL     0.37             179  0.33
# 2199    Rodriguez, Grayson   680570         SL     0.37             288  0.29
# 1234          Jacques, Joe   682175         SL     0.37             152  0.37
# 423         Castro, Miguel   612434         SL     0.37             384  0.34
# 2765          Walker, Ryan   676254         SL     0.37             492  0.32
# 1565        Luzardo, Jesús   666200         SL     0.36             765  0.38
# 1257         Jiménez, Dany   666204         SL     0.36             173  0.31
# 1056        Harvey, Hunter   640451         SL     0.36             111  0.23
# 1874         Muñoz, Andrés   662253         SL     0.36             377  0.40
# 519          Cosgrove, Tom   676680         SL     0.36             383  0.34
# 2129          Ragans, Cole   666142         SL     0.36             146  0.36
# 17            Abreu, Bryan   650556         SL     0.36             578  0.38
# 2099           Pérez, Eury   691587         SL     0.36             459  0.35
# 2525      Strider, Spencer   675911         SL     0.36             955  0.42
# 528          Cousins, Jake   664776         SL     0.35             110  0.33
# 1765         Miller, Bobby   676272         SL     0.35             299  0.23
# 2864       Williams, Gavin   668909         SL     0.35             288  0.33
# 417         Castillo, Luis   622491         SL     0.35             644  0.36
# 31              Adcock, Ty   686654         SL     0.35             116  0.27
# 1022           Hader, Josh   623352         SL     0.35             207  0.37
# 1005        Greene, Hunter   668881         SL     0.35             716  0.32
# 105       Ashcraft, Graham   668933         SL     0.35             868  0.32
# 2489       Stephan, Trevor   663986         SL     0.35             256  0.30
# 1702     McClanahan, Shane   663556         SL     0.35             278  0.33
# 1101         Herget, Jimmy   623474         SL     0.35             127  0.28
# 2438        Snider, Collin   676092         SL     0.35             105  0.25
# 1939         Okert, Steven   595345         SL     0.35             556  0.33
# 2403         Skubal, Tarik   669373         SL     0.35             234  0.24
# 2394           Sims, Lucas   608371         SL     0.35             500  0.36
# 2366        Severino, Luis   622663         SL     0.35             303  0.32
# 2212      Rodríguez, Yerry   666720         SL     0.35             103  0.26
# 2279           Sale, Chris   519242         SL     0.35             557  0.36
# 2308       Santos, Gregory   666619         SL     0.35             551  0.35
# 2316           Sborz, Josh   622250         SL     0.35             307  0.36
# 737        Fairbanks, Pete   664126         SL     0.34             327  0.38
# 751           Farmer, Buck   571656         SL     0.34             371  0.40
# 2895      Winckowski, Josh   670174         SL     0.34             210  0.28
# 977      Graterol, Brusdar   660813         SL     0.34             212  0.28
# 724           Erceg, Lucas   668674         SL     0.34             148  0.31
# 666          Doval, Camilo   666808         SL     0.34             372  0.36
# 2725            Vest, Will   676684         SL     0.34             238  0.26

# %%
df2['xgb_csw'].mean().round(2)
# Out:
# 0.28

# %%
top_pitches(df2, 'FS', min_pitches=100, top_n=50)
# Out:
#              player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw
# 177      Bautista, Félix   642585         FS     0.35             242  0.37
# 1055      Harvey, Hunter   640451         FS     0.33             163  0.27
# 1038       Harris, Hobie   665048         FS     0.32             175  0.27
# 775       Finnegan, Kyle   640448         FS     0.31             259  0.30
# 690         Duran, Jhoan   661395         FS     0.30             258  0.24
# 2904        Winn, Keaton   676775         FS     0.30             286  0.31
# 1494       Littell, Zack   641793         FS     0.29             219  0.21
# 1904       Neris, Hector   593576         FS     0.28             265  0.28
# 2573       Swanson, Erik   657024         FS     0.28             448  0.32
# 1372       Kirby, George   669923         FS     0.28             135  0.24
# 2381      Shreve, Chasen   592741         FS     0.27             305  0.23
# 899       Gausman, Kevin   592332         FS     0.27            1093  0.27
# 189        Bednar, David   670280         FS     0.27             167  0.29
# 451      Chirinos, Yonny   630023         FS     0.27             341  0.23
# 565       Cruz, Fernando   518585         FS     0.27             355  0.37
# 1113   Hernández, Carlos   672578         FS     0.26             124  0.21
# 2389      Silseth, Chase   681217         FS     0.26             135  0.24
# 2476        Stanek, Ryne   592773         FS     0.26             150  0.25
# 718      Eovaldi, Nathan   543135         FS     0.26             536  0.26
# 953       Gonsolin, Tony   664062         FS     0.26             452  0.22
# 917       Gilbert, Logan   669302         FS     0.26             381  0.25
# 541     Crawford, Kutter   676710         FS     0.26             144  0.20
# 2260           Ryan, Joe   657746         FS     0.25             670  0.21
# 330        Brown, Hunter   686613         FS     0.25             116  0.22
# 826   Fujinami, Shintaro   660261         FS     0.25             255  0.25
# 1992       Pagán, Emilio   641941         FS     0.25             124  0.25
# 1153       Hoffman, Jeff   656546         FS     0.24             151  0.24
# 1176       Houck, Tanner   656557         FS     0.24             163  0.26
# 1479    Leiter Jr., Mark   643410         FS     0.24             346  0.28
# 1711      McGough, Scott   543518         FS     0.24             486  0.29
# 1603        Maeda, Kenta   628317         FS     0.23             489  0.26
# 2114      Quantrill, Cal   615698         FS     0.23             102  0.11
# 2769     Walker, Taijuan   592836         FS     0.22             827  0.19
# 2952        Yates, Kirby   489446         FS     0.22             454  0.24
# 1778      Miller, Shelby   571946         FS     0.22             143  0.20
# 2158          Rea, Colin   607067         FS     0.21             103  0.17
# 1935      Ohtani, Shohei   660271         FS     0.21             134  0.22
# 2488     Stephan, Trevor   663986         FS     0.21             281  0.29
# 2534     Stroman, Marcus   573186         FS     0.21             155  0.18
# 1338        Kennedy, Ian   453178         FS     0.20             106  0.28
# 483           Cobb, Alex   502171         FS     0.20             944  0.19
# 164       Bassitt, Chris   605135         FS     0.20             102  0.18
# 2653    Toussaint, Touki   657053         FS     0.19             257  0.25
# 592          Darvish, Yu   506433         FS     0.19             171  0.26

# %%
top_pitches(df2, 'FF', min_pitches=100, top_n=50)
# Out:
#             player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw
# 2150    Rasmussen, Drew   656876         FF     0.37             199  0.29
# 1085    Hendricks, Kyle   543294         FF     0.34             398  0.35
# 1511       Lodolo, Nick   666157         FF     0.33             300  0.28
# 2336      Scott, Tanner   656945         FF     0.33             526  0.31
# 1781      Miller, Tyson   668338         FF     0.33             131  0.24
# 1187      Hudson, Bryan   663542         FF     0.33             142  0.38
# 1667        Maton, Phil   664208         FF     0.32             306  0.25
# 1259       Jiménez, Joe   641729         FF     0.32             535  0.30
# 278      Bradford, Cody   674003         FF     0.32             440  0.32
# 1322     Kelly, Merrill   518876         FF     0.32             742  0.32
# 2089          Puk, A.J.   640462         FF     0.32             440  0.37
# 1024           Hall, DL   669084         FF     0.32             129  0.31
# 1358     Kimbrel, Craig   518886         FF     0.32             691  0.32
# 2171     Reyes, Gerardo   622103         FF     0.32             118  0.33
# 1991      Pagán, Emilio   641941         FF     0.32             526  0.26
# 2367       Sewald, Paul   623149         FF     0.32             569  0.31
# 850         Gallen, Zac   668678         FF     0.32            1448  0.30
# 2524   Strider, Spencer   675911         FF     0.32            1653  0.30
# 654       Diekman, Jake   518617         FF     0.32             530  0.33
# 658         Dodd, Dylan   689266         FF     0.32             238  0.24
# 54     Alexander, Tyler   641302         FF     0.32             189  0.32
# 2750   Wainwright, Adam   425794         FF     0.31             173  0.31
# 225       Bieber, Shane   669456         FF     0.31             612  0.33
# 2717        Vesia, Alex   681911         FF     0.31             528  0.29
# 2409    Smeltzer, Devin   656970         FF     0.31             144  0.26
# 863      Garcia, Robert   676395         FF     0.31             197  0.27
# 898      Gausman, Kevin   592332         FF     0.31            1445  0.31
# 1009      Greinke, Zack   425844         FF     0.31             531  0.32
# 2519    Stratton, Chris   608717         FF     0.31             692  0.32
# 2098        Pérez, Eury   691587         FF     0.31             655  0.27
# 2119      Quijada, José   650671         FF     0.31             136  0.29
# 2226          Rom, Drew   680723         FF     0.31             182  0.25
# 2320      Scherzer, Max   453286         FF     0.31            1142  0.29
# 2049    Pfaadt, Brandon   694297         FF     0.31             675  0.26
# 1950         Ort, Kaleb   672391         FF     0.31             276  0.23
# 1788       Milner, Hoby   571948         FF     0.31             201  0.26
# 38         Akin, Keegan   669211         FF     0.31             271  0.32
# 1470         Lee, Dylan   669276         FF     0.31             157  0.24
# 1908      Newcomb, Sean   656794         FF     0.31             145  0.24
# 176     Bautista, Félix   642585         FF     0.31             696  0.34
# 1919        Nola, Aaron   605400         FF     0.30             857  0.31
# 1777     Miller, Shelby   571946         FF     0.30             316  0.37
# 2640    Thornton, Trent   663423         FF     0.30             133  0.31
# 1606       Mahle, Tyler   641816         FF     0.30             218  0.31
# 728   Estrada, Jeremiah   669093         FF     0.30             199  0.22
# 734         Faedo, Alex   656412         FF     0.30             502  0.26
# 2501     Stewart, Brock   592779         FF     0.30             151  0.48
# 1580        Lynn, Lance   458681         FF     0.30            1237  0.31
# 1710     McGough, Scott   543518         FF     0.30             630  0.31
# 804        France, J.P.   641585         FF     0.30             902  0.25

# %%
top_pitches(df2, 'CH', min_pitches=100, top_n=50)
# Out:
#              player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw
# 2195  Rodriguez, Grayson   680570         CH     0.37             419  0.25
# 2858     Williams, Devin   642207         CH     0.36             507  0.33
# 2399       Skubal, Tarik   669373         CH     0.33             245  0.39
# 1817         Moore, Matt   519043         CH     0.32             237  0.30
# 1039       Harris, Hogan   663687         CH     0.32             225  0.36
# 2174    Richards, Trevor   670950         CH     0.32             675  0.38
# 2023        Pepiot, Ryan   686752         CH     0.32             139  0.29
# 1699   McClanahan, Shane   663556         CH     0.32             469  0.37
# 2134       Ramirez, Nick   598286         CH     0.31             171  0.26
# 644      Devenski, Chris   606965         CH     0.31             307  0.30
# 301    Brazoban, Huascar   623211         CH     0.31             271  0.28
# 1761       Miller, Bobby   676272         CH     0.31             264  0.28
# 2742      Wacha, Michael   608379         CH     0.31             646  0.31
# 2125        Ragans, Cole   666142         CH     0.31             331  0.26
# 2929   Woodruff, Brandon   605540         CH     0.31             170  0.25
# 2236    Rosenberg, Kenny   670046         CH     0.31             124  0.26
# 1832         Morgan, Eli   669212         CH     0.30             333  0.31
# 211        Bibee, Tanner   676440         CH     0.30             386  0.33
# 932       Giolito, Lucas   608337         CH     0.30             766  0.33
# 946       Gomber, Austin   596295         CH     0.30             390  0.24
# 1767       Miller, Bryce   682243         CH     0.30             104  0.19
# 2849   Whitlock, Garrett   676477         CH     0.30             255  0.27
# 1397      Kowar, Jackson   663804         CH     0.30             162  0.23
# 112         Avila, Pedro   658648         CH     0.29             176  0.31
# 1654      Martinez, Nick   607259         CH     0.29             446  0.33
# 2557        Suter, Brent   608718         CH     0.29             291  0.30
# 77       Anderson, Chase   502624         CH     0.29             271  0.24
# 1747   Middleton, Keynan   641871         CH     0.29             361  0.37
# 1822       Moran, Jovani   663558         CH     0.29             354  0.35
# 1812  Montgomery, Jordan   656756         CH     0.29             602  0.27
# 1750      Mikolas, Miles   571945         CH     0.29             163  0.14
# 1663    Martínez, Adrián   661309         CH     0.28             205  0.23
# 711       Englert, Mason   669438         CH     0.28             256  0.19
# 1928        Ober, Bailey   641927         CH     0.28             543  0.28
# 2232        Romero, JoJo   668941         CH     0.28             153  0.37
# 1171    Honeywell, Brent   641703         CH     0.28             250  0.24
# 1220      Jackson, Andre   656578         CH     0.28             275  0.28
# 2276         Sale, Chris   519242         CH     0.28             190  0.31
# 1670        Matz, Steven   571927         CH     0.28             494  0.27
# 2014       Payamps, Joel   606303         CH     0.28             128  0.23
# 1534         Loup, Aaron   571901         CH     0.28             138  0.26
# 1561      Luzardo, Jesús   666200         CH     0.28             581  0.27
# 1588        López, Pablo   641154         CH     0.28             589  0.25
# 2432        Snell, Blake   605483         CH     0.28             540  0.37
# 1679         May, Trevor   543507         CH     0.28             154  0.32
# 2362      Severino, Luis   622663         CH     0.28             304  0.23
# 1898        Nelson, Ryne   669194         CH     0.28             303  0.22
# 1102       Herget, Kevin   643361         CH     0.28             147  0.20
# 414       Castillo, Luis   622491         CH     0.28             455  0.27
# 652        Diekman, Jake   518617         CH     0.28             137  0.22

# %%
df2['xgb_csw_percentile'] = df2['xgb_csw'].rank(pct=True).round(2).mul(100).astype(int)

# %%
df2.sample(10)
# Out:
#            player_name  pitcher pitch_type  xgb_csw  pitches_thrown   csw  \
# 437     Chafin, Andrew   605177         SI     0.24             364  0.29
# 2450     Soriano, José   667755         SL     0.30              33  0.33
# 55    Alexander, Tyler   641302         SI     0.31              76  0.30
# 325       Brito, Jhony   666745         SL     0.20              20  0.10
# 2357      Senga, Kodai   673540         ST     0.34             156  0.33
# 2233      Romero, JoJo   668941         FF     0.19              85  0.21
# 1148     Hoeing, Bryan   663773         CH     0.23              62  0.15
# 300      Brasier, Ryan   518489         SL     0.34             298  0.28
# 1954    Ortega, Oliver   661383         SI     0.24              41  0.27
# 2326   Schmidt, Clarke   657376         ST     0.34             674  0.36
#
#       xgb_csw_percentile
# 437                   22
# 2450                  70
# 55                    77
# 325                    6
# 2357                  92
# 2233                   4
# 1148                  16
# 300                   92
# 1954                  22
# 2326                  92

# %%
df2.to_csv('csw_pitcher_predictions.csv', index=False)

# %%
df_holdout.to_csv('csw_model_predictions.csv')
